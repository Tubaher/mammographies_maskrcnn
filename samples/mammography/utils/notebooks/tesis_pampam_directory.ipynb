# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls
# Out:
# gdrive	sample_data

# %%
# %cd gdrive/MyDrive/Tesis_Pampam/mammographies_maskrcnn/samples/mammography/
# Out:
# /content/gdrive/MyDrive/Tesis_Pampam/mammographies_maskrcnn/samples/mammography

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !python train.py --dataset stuff/dataset/ --weights coco --logs stuff/logs/dcomplete_pcoco/
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /content/gdrive/MyDrive/Tesis_Pampam/mammographies_maskrcnn/mrcnn/model.py:37: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /content/gdrive/MyDrive/Tesis_Pampam/mammographies_maskrcnn/mrcnn/model.py:41: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2021-02-09 20:38:25.438229: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX512F
# 2021-02-09 20:38:25.462985: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2000134999 Hz
# 2021-02-09 20:38:25.463223: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x282ca00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# ...
